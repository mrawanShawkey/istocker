# %%
import sys
from pathlib import Path

ROOT_DIR = Path().resolve().parents[1]
sys.path.append(str(ROOT_DIR))
from config.paths import XGBOOST_RESULTS_FILE as results_path
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(results_path)
print(df.columns)
print(df.head())
# Out:
# Index(['fold', 'rmse', 'mae', 'r2', 'directional_accuracy',
#        'information_coefficient', 'spearman_ic', 'sign_hit_rate', 'pred_mean',
#        'pred_std', 'actual_mean', 'actual_std', 'n_preds', 'r2_out_of_sample',
#        'preds', 'y_true'],
#       dtype='object')
#    fold      rmse       mae        r2  directional_accuracy  \
# 0     1  0.311034  0.255503  0.044568              0.685095
# 1     2  0.302396  0.239587 -0.044281              0.822950
# 2     3  0.572410  0.422705 -0.167394              0.459153
# 3     4  0.646775  0.551951 -1.714281              0.247225
# 4     5  0.763229  0.646960 -1.309193              0.432703
#
#    information_coefficient  spearman_ic  sign_hit_rate  pred_mean  pred_std  \
# 0                 0.497405     0.483826       0.685095   0.252308  0.217075
# 1                 0.378866     0.356029       0.822950   0.221864  0.203946
# 2                 0.054462    -0.099825       0.459153   0.139351  0.233299
# 3                 0.046960     0.034204       0.247225   0.246980  0.146762
# 4                 0.101174     0.105376       0.432703   0.006356  0.206885
#
#    actual_mean  actual_std  n_preds  r2_out_of_sample  \
# 0     0.121611    0.318206     4938          0.256641
# 1     0.311381    0.295915     5072          0.649890
# 2     0.061781    0.529784     5288         -0.106433
# 3    -0.251089    0.392578     5226         -0.935086
# 4     0.561768    0.502256     5290         -0.040655
#
#                                                preds  \
# 0  [-0.024446019902825356, -0.08236891776323318, ...
# 1  [-0.075888991355896, -0.075888991355896, -0.07...
# 2  [-0.3626726269721985, -0.33291926980018616, -0...
# 3  [0.06799613684415817, 0.07758408784866333, 0.0...
# 4  [0.020769856870174408, 0.020769856870174408, -...
#
#                                               y_true
# 0  [0.0995661905369815, -0.0028947895694931, -0.0...
# 1  [0.1297949894606597, 0.1562060335093835, 0.161...
# 2  [0.1225974011609666, 0.1458293640765363, 0.150...
# 3  [-0.2082315237424255, -0.2036427657063806, -0....
# 4  [-0.4036352805640625, -0.4036352805640625, -0....

# %%
import sys
from pathlib import Path

ROOT_DIR = Path().resolve().parents[1]
sys.path.append(str(ROOT_DIR)) 
import pandas as pd
from config.paths import XGBOOST_RESULTS_FILE as results_path


df = pd.read_csv(results_path)
print(df.columns)
df.head()
# Out:
# Index(['fold', 'rmse', 'mae', 'r2', 'directional_accuracy',
#        'information_coefficient', 'spearman_ic', 'sign_hit_rate', 'pred_mean',
#        'pred_std', 'actual_mean', 'actual_std', 'n_preds', 'r2_out_of_sample',
#        'preds', 'y_true'],
#       dtype='object')
#    fold      rmse       mae        r2  directional_accuracy  \
# 0     1  0.317419  0.261521  0.004942              0.682260
# 1     2  0.306343  0.244129 -0.071720              0.817626
# 2     3  0.571908  0.421156 -0.165347              0.464448
# 3     4  0.651153  0.556841 -1.751147              0.244355
# 4     5  0.779115  0.662951 -1.406324              0.412854
#
#    information_coefficient  spearman_ic  sign_hit_rate  pred_mean  pred_std  \
# 0                 0.495858     0.483532       0.682260   0.262365  0.225491
# 1                 0.362682     0.334179       0.817626   0.226530  0.210273
# 2                 0.061883    -0.085135       0.464448   0.137623  0.237066
# 3                 0.054510     0.035720       0.244355   0.253883  0.145270
# 4                 0.111497     0.104977       0.412854  -0.013075  0.221684
#
#    actual_mean  actual_std  n_preds  r2_out_of_sample  \
# 0     0.121611    0.318206     4938          0.225812
# 1     0.311381    0.295915     5072          0.640691
# 2     0.061781    0.529784     5288         -0.104493
# 3    -0.251089    0.392578     5226         -0.961370
# 4     0.561768    0.502256     5290         -0.084427
#
#                                                preds  \
# 0  [-0.017757782712578773, -0.07961608469486237, ...
# 1  [-0.09557254612445831, -0.09543364495038986, -...
# 2  [-0.3916870951652527, -0.3395395576953888, -0....
# 3  [0.07431337982416153, 0.08296927064657211, 0.0...
# 4  [-0.005982831120491028, -0.005982831120491028,...
#
#                                               y_true
# 0  [0.0995661905369815, -0.0028947895694931, -0.0...
# 1  [0.1297949894606597, 0.1562060335093835, 0.161...
# 2  [0.1225974011609666, 0.1458293640765363, 0.150...
# 3  [-0.2082315237424255, -0.2036427657063806, -0....
# 4  [-0.4036352805640625, -0.4036352805640625, -0....
